# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %%
#Import the requests library
import requests

#Import API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Processing Record 1 of Set 1 | sinnamary
# Processing Record 2 of Set 1 | kruisfontein
# Processing Record 3 of Set 1 | thompson
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | morant bay
# Processing Record 6 of Set 1 | progreso
# Processing Record 7 of Set 1 | taoudenni
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | xai-xai
# Processing Record 10 of Set 1 | cheboksary
# Processing Record 11 of Set 1 | northam
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | zhigansk
# Processing Record 14 of Set 1 | impfondo
# Processing Record 15 of Set 1 | manaus
# Processing Record 16 of Set 1 | tara
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | disa
# Processing Record 19 of Set 1 | maragogi
# Processing Record 20 of Set 1 | butaritari
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | castro
# Processing Record 23 of Set 1 | akyab
# Processing Record 24 of Set 1 | agva
# City not found. Skipping...
# Processing Record 25 of Set 1 | new norfolk
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | ascension
# Processing Record 28 of Set 1 | victoria
# Processing Record 29 of Set 1 | kodiak
# Processing Record 30 of Set 1 | tynda
# Processing Record 31 of Set 1 | fort myers beach
# Processing Record 32 of Set 1 | isangel
# Processing Record 33 of Set 1 | porto santo
# Processing Record 34 of Set 1 | hofn
# Processing Record 35 of Set 1 | lata
# Processing Record 36 of Set 1 | erenhot
# Processing Record 37 of Set 1 | port hedland
# Processing Record 38 of Set 1 | saravan
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | divo
# Processing Record 41 of Set 1 | hithadhoo
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | general pico
# Processing Record 44 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 1 | gunjur
# Processing Record 46 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 1 | hare bay
# Processing Record 48 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | mahebourg
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | saint george
# Processing Record 3 of Set 2 | yulara
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | casablanca
# Processing Record 6 of Set 2 | punta arenas
# Processing Record 7 of Set 2 | safaga
# Processing Record 8 of Set 2 | saint-philippe
# Processing Record 9 of Set 2 | olinda
# Processing Record 10 of Set 2 | bodden town
# Processing Record 11 of Set 2 | tuktoyaktuk
# Processing Record 12 of Set 2 | behbahan
# Processing Record 13 of Set 2 | kemijarvi
# Processing Record 14 of Set 2 | namibe
# Processing Record 15 of Set 2 | beloha
# Processing Record 16 of Set 2 | karratha
# Processing Record 17 of Set 2 | nelson bay
# Processing Record 18 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 2 | upernavik
# Processing Record 20 of Set 2 | eldikan
# City not found. Skipping...
# Processing Record 21 of Set 2 | aklavik
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | awbari
# Processing Record 24 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 2 | henties bay
# Processing Record 26 of Set 2 | kavaratti
# Processing Record 27 of Set 2 | gazanjyk
# Processing Record 28 of Set 2 | dikson
# Processing Record 29 of Set 2 | bubaque
# Processing Record 30 of Set 2 | celestun
# Processing Record 31 of Set 2 | jamestown
# Processing Record 32 of Set 2 | kalmunai
# Processing Record 33 of Set 2 | bethel
# Processing Record 34 of Set 2 | husavik
# Processing Record 35 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 2 | hay river
# Processing Record 37 of Set 2 | balkhash
# Processing Record 38 of Set 2 | bengkulu
# Processing Record 39 of Set 2 | busselton
# Processing Record 40 of Set 2 | gillette
# Processing Record 41 of Set 2 | veraval
# Processing Record 42 of Set 2 | lavrentiya
# Processing Record 43 of Set 2 | taltal
# Processing Record 44 of Set 2 | asau
# Processing Record 45 of Set 2 | puerto ayora
# Processing Record 46 of Set 2 | lapua
# Processing Record 47 of Set 2 | mount gambier
# Processing Record 48 of Set 2 | chuy
# Processing Record 49 of Set 2 | mount isa
# Processing Record 50 of Set 2 | palizada
# Processing Record 1 of Set 3 | port augusta
# Processing Record 2 of Set 3 | bluff
# Processing Record 3 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 3 | mujiayingzi
# Processing Record 5 of Set 3 | hirara
# Processing Record 6 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 3 | kurilsk
# Processing Record 8 of Set 3 | nanortalik
# Processing Record 9 of Set 3 | hambantota
# Processing Record 10 of Set 3 | bambanglipuro
# Processing Record 11 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 3 | cherskiy
# Processing Record 13 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 3 | tupik
# Processing Record 15 of Set 3 | biak
# Processing Record 16 of Set 3 | faanui
# Processing Record 17 of Set 3 | provideniya
# Processing Record 18 of Set 3 | airai
# Processing Record 19 of Set 3 | carnarvon
# Processing Record 20 of Set 3 | flin flon
# Processing Record 21 of Set 3 | lorengau
# Processing Record 22 of Set 3 | ahipara
# Processing Record 23 of Set 3 | kirakira
# Processing Record 24 of Set 3 | quatre cocos
# Processing Record 25 of Set 3 | aksarka
# Processing Record 26 of Set 3 | hobart
# Processing Record 27 of Set 3 | katangli
# Processing Record 28 of Set 3 | mariinsk
# Processing Record 29 of Set 3 | banda aceh
# Processing Record 30 of Set 3 | ostrovnoy
# Processing Record 31 of Set 3 | cortez
# Processing Record 32 of Set 3 | port alfred
# Processing Record 33 of Set 3 | kuhestan
# City not found. Skipping...
# Processing Record 34 of Set 3 | tasiilaq
# Processing Record 35 of Set 3 | buguda
# Processing Record 36 of Set 3 | salalah
# Processing Record 37 of Set 3 | saskylakh
# Processing Record 38 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 39 of Set 3 | soe
# Processing Record 40 of Set 3 | kiunga
# Processing Record 41 of Set 3 | verkhnevilyuysk
# Processing Record 42 of Set 3 | tabou
# Processing Record 43 of Set 3 | ambon
# Processing Record 44 of Set 3 | citrus park
# Processing Record 45 of Set 3 | guerrero negro
# Processing Record 46 of Set 3 | tulum
# Processing Record 47 of Set 3 | ciudad real
# Processing Record 48 of Set 3 | fayaoue
# Processing Record 49 of Set 3 | ureki
# Processing Record 50 of Set 3 | yar-sale
# Processing Record 1 of Set 4 | longyearbyen
# Processing Record 2 of Set 4 | yamada
# Processing Record 3 of Set 4 | tuatapere
# Processing Record 4 of Set 4 | jieshi
# Processing Record 5 of Set 4 | dingle
# Processing Record 6 of Set 4 | marsaxlokk
# Processing Record 7 of Set 4 | kango
# Processing Record 8 of Set 4 | kavieng
# Processing Record 9 of Set 4 | meulaboh
# Processing Record 10 of Set 4 | aleksandrov gay
# Processing Record 11 of Set 4 | tecoanapa
# Processing Record 12 of Set 4 | tessalit
# Processing Record 13 of Set 4 | la ronge
# Processing Record 14 of Set 4 | jalu
# Processing Record 15 of Set 4 | cocobeach
# Processing Record 16 of Set 4 | acapulco
# Processing Record 17 of Set 4 | vila velha
# Processing Record 18 of Set 4 | severo-kurilsk
# Processing Record 19 of Set 4 | berlevag
# Processing Record 20 of Set 4 | udachnyy
# Processing Record 21 of Set 4 | beringovskiy
# Processing Record 22 of Set 4 | vanimo
# Processing Record 23 of Set 4 | marsa matruh
# Processing Record 24 of Set 4 | makakilo city
# Processing Record 25 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 4 | byron bay
# Processing Record 27 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 28 of Set 4 | roseburg
# Processing Record 29 of Set 4 | maarianhamina
# Processing Record 30 of Set 4 | rawson
# Processing Record 31 of Set 4 | mbandaka
# Processing Record 32 of Set 4 | flinders
# Processing Record 33 of Set 4 | bambous virieux
# Processing Record 34 of Set 4 | sibolga
# Processing Record 35 of Set 4 | ankola
# Processing Record 36 of Set 4 | dunedin
# Processing Record 37 of Set 4 | benghazi
# Processing Record 38 of Set 4 | teofilo otoni
# Processing Record 39 of Set 4 | nikolskoye
# Processing Record 40 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 41 of Set 4 | chokurdakh
# Processing Record 42 of Set 4 | kloulklubed
# Processing Record 43 of Set 4 | amuntai
# Processing Record 44 of Set 4 | arraial do cabo
# Processing Record 45 of Set 4 | barrow
# Processing Record 46 of Set 4 | monrovia
# Processing Record 47 of Set 4 | auray
# Processing Record 48 of Set 4 | mirnyy
# Processing Record 49 of Set 4 | hilo
# Processing Record 50 of Set 4 | mayskiy
# Processing Record 1 of Set 5 | thinadhoo
# Processing Record 2 of Set 5 | dandong
# Processing Record 3 of Set 5 | dicabisagan
# Processing Record 4 of Set 5 | huarmey
# Processing Record 5 of Set 5 | alpena
# Processing Record 6 of Set 5 | yining
# Processing Record 7 of Set 5 | garden city
# Processing Record 8 of Set 5 | masvingo
# Processing Record 9 of Set 5 | khatanga
# Processing Record 10 of Set 5 | camacha
# Processing Record 11 of Set 5 | molde
# Processing Record 12 of Set 5 | xichang
# Processing Record 13 of Set 5 | bandarbeyla
# Processing Record 14 of Set 5 | arrecife
# Processing Record 15 of Set 5 | aasiaat
# Processing Record 16 of Set 5 | praia
# Processing Record 17 of Set 5 | dukat
# Processing Record 18 of Set 5 | tonk
# Processing Record 19 of Set 5 | inhambane
# Processing Record 20 of Set 5 | katsuura
# Processing Record 21 of Set 5 | clyde river
# Processing Record 22 of Set 5 | itoman
# Processing Record 23 of Set 5 | kahului
# Processing Record 24 of Set 5 | hagere hiywet
# Processing Record 25 of Set 5 | ribeira grande
# Processing Record 26 of Set 5 | pangnirtung
# Processing Record 27 of Set 5 | los llanos de aridane
# Processing Record 28 of Set 5 | cap malheureux
# Processing Record 29 of Set 5 | killybegs
# Processing Record 30 of Set 5 | primorsk
# Processing Record 31 of Set 5 | marovoay
# Processing Record 32 of Set 5 | souillac
# Processing Record 33 of Set 5 | ancud
# Processing Record 34 of Set 5 | lompoc
# Processing Record 35 of Set 5 | nurota
# Processing Record 36 of Set 5 | hamilton
# Processing Record 37 of Set 5 | vikhorevka
# Processing Record 38 of Set 5 | port elizabeth
# Processing Record 39 of Set 5 | ballina
# Processing Record 40 of Set 5 | nazarovo
# Processing Record 41 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 42 of Set 5 | batagay
# Processing Record 43 of Set 5 | port hardy
# Processing Record 44 of Set 5 | atuona
# Processing Record 45 of Set 5 | qasigiannguit
# Processing Record 46 of Set 5 | mayo
# Processing Record 47 of Set 5 | kyren
# Processing Record 48 of Set 5 | parras
# City not found. Skipping...
# Processing Record 49 of Set 5 | tautira
# Processing Record 50 of Set 5 | codrington
# Processing Record 1 of Set 6 | harper
# Processing Record 2 of Set 6 | balabac
# Processing Record 3 of Set 6 | sitka
# Processing Record 4 of Set 6 | iracoubo
# Processing Record 5 of Set 6 | carauari
# Processing Record 6 of Set 6 | cidreira
# Processing Record 7 of Set 6 | tateyama
# Processing Record 8 of Set 6 | caucaia
# Processing Record 9 of Set 6 | san carlos
# Processing Record 10 of Set 6 | bilibino
# Processing Record 11 of Set 6 | uige
# Processing Record 12 of Set 6 | mocuba
# Processing Record 13 of Set 6 | majene
# Processing Record 14 of Set 6 | talcahuano
# Processing Record 15 of Set 6 | te anau
# Processing Record 16 of Set 6 | atar
# Processing Record 17 of Set 6 | gangakher
# Processing Record 18 of Set 6 | ust-kuyga
# Processing Record 19 of Set 6 | east london
# Processing Record 20 of Set 6 | paita
# Processing Record 21 of Set 6 | likasi
# Processing Record 22 of Set 6 | moerai
# Processing Record 23 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 6 | anadyr
# Processing Record 25 of Set 6 | bonthe
# Processing Record 26 of Set 6 | port-gentil
# Processing Record 27 of Set 6 | kholodnyy
# Processing Record 28 of Set 6 | gao
# Processing Record 29 of Set 6 | faya
# Processing Record 30 of Set 6 | ondjiva
# Processing Record 31 of Set 6 | briancon
# Processing Record 32 of Set 6 | tezu
# Processing Record 33 of Set 6 | necochea
# Processing Record 34 of Set 6 | mogadishu
# Processing Record 35 of Set 6 | pisco
# Processing Record 36 of Set 6 | vardo
# Processing Record 37 of Set 6 | san cristobal
# Processing Record 38 of Set 6 | leningradskiy
# Processing Record 39 of Set 6 | villa union
# Processing Record 40 of Set 6 | sungairaya
# Processing Record 41 of Set 6 | robertsport
# Processing Record 42 of Set 6 | ozinki
# Processing Record 43 of Set 6 | kaitangata
# Processing Record 44 of Set 6 | norman wells
# Processing Record 45 of Set 6 | muroto
# Processing Record 46 of Set 6 | mar del plata
# Processing Record 47 of Set 6 | markova
# Processing Record 48 of Set 6 | sao miguel do araguaia
# Processing Record 49 of Set 6 | upington
# Processing Record 50 of Set 6 | katsina
# Processing Record 1 of Set 7 | the valley
# Processing Record 2 of Set 7 | novouzensk
# Processing Record 3 of Set 7 | sakyla
# Processing Record 4 of Set 7 | high level
# Processing Record 5 of Set 7 | lewiston
# Processing Record 6 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 7 | sovetskiy
# Processing Record 8 of Set 7 | pastavy
# Processing Record 9 of Set 7 | narsaq
# Processing Record 10 of Set 7 | hasaki
# Processing Record 11 of Set 7 | gien
# Processing Record 12 of Set 7 | sao joao da barra
# Processing Record 13 of Set 7 | mushie
# Processing Record 14 of Set 7 | westport
# Processing Record 15 of Set 7 | oron
# Processing Record 16 of Set 7 | gizo
# Processing Record 17 of Set 7 | georgetown
# Processing Record 18 of Set 7 | pedro velho
# Processing Record 19 of Set 7 | kautokeino
# Processing Record 20 of Set 7 | torbay
# Processing Record 21 of Set 7 | coracora
# Processing Record 22 of Set 7 | abu dhabi
# Processing Record 23 of Set 7 | laguna
# Processing Record 24 of Set 7 | sur
# Processing Record 25 of Set 7 | gort
# Processing Record 26 of Set 7 | honolulu
# Processing Record 27 of Set 7 | sao filipe
# Processing Record 28 of Set 7 | sokolka
# Processing Record 29 of Set 7 | lar
# Processing Record 30 of Set 7 | sampit
# Processing Record 31 of Set 7 | lebu
# Processing Record 32 of Set 7 | chapais
# Processing Record 33 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 34 of Set 7 | lere
# Processing Record 35 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 7 | ust-nera
# Processing Record 37 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 7 | sandviken
# Processing Record 39 of Set 7 | moroni
# Processing Record 40 of Set 7 | san quintin
# Processing Record 41 of Set 7 | mehamn
# Processing Record 42 of Set 7 | sorland
# Processing Record 43 of Set 7 | lagoa
# Processing Record 44 of Set 7 | pachino
# Processing Record 45 of Set 7 | tiksi
# Processing Record 46 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 7 | healdsburg
# Processing Record 48 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 7 | sangar
# Processing Record 50 of Set 7 | salo
# Processing Record 1 of Set 8 | ipixuna
# Processing Record 2 of Set 8 | barabai
# Processing Record 3 of Set 8 | krasnoselkup
# Processing Record 4 of Set 8 | pevek
# Processing Record 5 of Set 8 | omsukchan
# Processing Record 6 of Set 8 | nago
# Processing Record 7 of Set 8 | arcata
# Processing Record 8 of Set 8 | am timan
# Processing Record 9 of Set 8 | olsztyn
# Processing Record 10 of Set 8 | davila
# Processing Record 11 of Set 8 | sheridan
# Processing Record 12 of Set 8 | aswan
# Processing Record 13 of Set 8 | kirensk
# Processing Record 14 of Set 8 | homer
# Processing Record 15 of Set 8 | praia da vitoria
# Processing Record 16 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 8 | aransas pass
# Processing Record 18 of Set 8 | egvekinot
# Processing Record 19 of Set 8 | esperance
# Processing Record 20 of Set 8 | coronel oviedo
# Processing Record 21 of Set 8 | kendari
# Processing Record 22 of Set 8 | princeton
# Processing Record 23 of Set 8 | ponta do sol
# Processing Record 24 of Set 8 | chara
# Processing Record 25 of Set 8 | noumea
# Processing Record 26 of Set 8 | sobolevo
# Processing Record 27 of Set 8 | berdigestyakh
# Processing Record 28 of Set 8 | charters towers
# Processing Record 29 of Set 8 | broken hill
# Processing Record 30 of Set 8 | lufilufi
# Processing Record 31 of Set 8 | sorong
# Processing Record 32 of Set 8 | sola
# Processing Record 33 of Set 8 | ilulissat
# Processing Record 34 of Set 8 | ahumada
# City not found. Skipping...
# Processing Record 35 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 36 of Set 8 | avera
# Processing Record 37 of Set 8 | umm kaddadah
# Processing Record 38 of Set 8 | tucupita
# Processing Record 39 of Set 8 | amazar
# Processing Record 40 of Set 8 | mulege
# Processing Record 41 of Set 8 | alofi
# Processing Record 42 of Set 8 | liangxiang
# Processing Record 43 of Set 8 | grand-bourg
# Processing Record 44 of Set 8 | cabedelo
# Processing Record 45 of Set 8 | ndele
# Processing Record 46 of Set 8 | hami
# Processing Record 47 of Set 8 | khorixas
# Processing Record 48 of Set 8 | la asuncion
# Processing Record 49 of Set 8 | opuwo
# Processing Record 50 of Set 8 | jamsa
# Processing Record 1 of Set 9 | san carlos de bariloche
# Processing Record 2 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 9 | yorkton
# Processing Record 4 of Set 9 | talnakh
# Processing Record 5 of Set 9 | bathsheba
# Processing Record 6 of Set 9 | basco
# Processing Record 7 of Set 9 | fortuna
# Processing Record 8 of Set 9 | abnub
# Processing Record 9 of Set 9 | tambun
# Processing Record 10 of Set 9 | qui nhon
# Processing Record 11 of Set 9 | pervomayskiy
# Processing Record 12 of Set 9 | lazaro cardenas
# Processing Record 13 of Set 9 | sayyan
# Processing Record 14 of Set 9 | obukhiv
# Processing Record 15 of Set 9 | oussouye
# Processing Record 16 of Set 9 | moindou
# Processing Record 17 of Set 9 | kaeo
# Processing Record 18 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 9 | lyuban
# Processing Record 20 of Set 9 | hovd
# Processing Record 21 of Set 9 | altagracia de orituco
# Processing Record 22 of Set 9 | abu samrah
# Processing Record 23 of Set 9 | zhongshu
# Processing Record 24 of Set 9 | dhidhdhoo
# Processing Record 25 of Set 9 | kattivakkam
# Processing Record 26 of Set 9 | klaksvik
# Processing Record 27 of Set 9 | kouroussa
# Processing Record 28 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 9 | moree
# Processing Record 30 of Set 9 | saint-augustin
# Processing Record 31 of Set 9 | nome
# Processing Record 32 of Set 9 | vestmannaeyjar
# Processing Record 33 of Set 9 | cumana
# Processing Record 34 of Set 9 | tanout
# Processing Record 35 of Set 9 | bay roberts
# Processing Record 36 of Set 9 | gorele
# Processing Record 37 of Set 9 | poole
# Processing Record 38 of Set 9 | kununurra
# Processing Record 39 of Set 9 | dien bien
# City not found. Skipping...
# Processing Record 40 of Set 9 | saint anthony
# Processing Record 41 of Set 9 | verkhniy tagil
# Processing Record 42 of Set 9 | obama
# Processing Record 43 of Set 9 | batsfjord
# Processing Record 44 of Set 9 | cayenne
# Processing Record 45 of Set 9 | tokmak
# Processing Record 46 of Set 9 | buchanan
# Processing Record 47 of Set 9 | winnemucca
# Processing Record 48 of Set 9 | xuddur
# Processing Record 49 of Set 9 | maine-soroa
# Processing Record 50 of Set 9 | fernandopolis
# Processing Record 1 of Set 10 | brooks
# Processing Record 2 of Set 10 | azanka
# Processing Record 3 of Set 10 | colares
# Processing Record 4 of Set 10 | russell
# Processing Record 5 of Set 10 | college
# Processing Record 6 of Set 10 | cochrane
# Processing Record 7 of Set 10 | garissa
# Processing Record 8 of Set 10 | aras
# Processing Record 9 of Set 10 | valle de allende
# Processing Record 10 of Set 10 | kargasok
# Processing Record 11 of Set 10 | cabo san lucas
# Processing Record 12 of Set 10 | makat
# Processing Record 13 of Set 10 | saldanha
# Processing Record 14 of Set 10 | valera
# Processing Record 15 of Set 10 | puerto suarez
# Processing Record 16 of Set 10 | pontianak
# Processing Record 17 of Set 10 | nador
# Processing Record 18 of Set 10 | andijon
# Processing Record 19 of Set 10 | akcakoca
# Processing Record 20 of Set 10 | sabang
# Processing Record 21 of Set 10 | lasa
# Processing Record 22 of Set 10 | coquimbo
# Processing Record 23 of Set 10 | bantry
# Processing Record 24 of Set 10 | rio gallegos
# Processing Record 25 of Set 10 | gat
# Processing Record 26 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 27 of Set 10 | matay
# Processing Record 28 of Set 10 | dongsheng
# Processing Record 29 of Set 10 | vila franca do campo
# Processing Record 30 of Set 10 | manaure
# Processing Record 31 of Set 10 | komsomolskiy
# Processing Record 32 of Set 10 | suhbaatar
# Processing Record 33 of Set 10 | sidhauli
# Processing Record 34 of Set 10 | rawlins
# Processing Record 35 of Set 10 | batticaloa
# Processing Record 36 of Set 10 | rondonopolis
# Processing Record 37 of Set 10 | tual
# Processing Record 38 of Set 10 | la serena
# Processing Record 39 of Set 10 | mattru
# Processing Record 40 of Set 10 | tucurui
# Processing Record 41 of Set 10 | brodokalmak
# Processing Record 42 of Set 10 | ladario
# Processing Record 43 of Set 10 | buriti bravo
# Processing Record 44 of Set 10 | burnie
# Processing Record 45 of Set 10 | nicoya
# Processing Record 46 of Set 10 | svetlogorsk
# Processing Record 47 of Set 10 | pombas
# Processing Record 48 of Set 10 | nishihara
# Processing Record 49 of Set 10 | salinopolis
# Processing Record 50 of Set 10 | arlit
# Processing Record 1 of Set 11 | chapada dos guimaraes
# Processing Record 2 of Set 11 | itarema
# Processing Record 3 of Set 11 | botngard
# Processing Record 4 of Set 11 | gabu
# Processing Record 5 of Set 11 | port blair
# Processing Record 6 of Set 11 | boves
# Processing Record 7 of Set 11 | tlacote el bajo
# Processing Record 8 of Set 11 | baykit
# Processing Record 9 of Set 11 | rabaul
# Processing Record 10 of Set 11 | olga
# Processing Record 11 of Set 11 | lerwick
# Processing Record 12 of Set 11 | wau
# Processing Record 13 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 14 of Set 11 | naron
# Processing Record 15 of Set 11 | masuda
# Processing Record 16 of Set 11 | geraldton
# Processing Record 17 of Set 11 | haines junction
# Processing Record 18 of Set 11 | yerbogachen
# Processing Record 19 of Set 11 | goure
# Processing Record 20 of Set 11 | cananeia
# Processing Record 21 of Set 11 | amapa
# Processing Record 22 of Set 11 | leh
# Processing Record 23 of Set 11 | setermoen
# Processing Record 24 of Set 11 | margate
# Processing Record 25 of Set 11 | carutapera
# Processing Record 26 of Set 11 | hualmay
# Processing Record 27 of Set 11 | timbo
# Processing Record 28 of Set 11 | darnah
# Processing Record 29 of Set 11 | basi
# Processing Record 30 of Set 11 | the pas
# Processing Record 31 of Set 11 | adet
# Processing Record 32 of Set 11 | coihaique
# Processing Record 33 of Set 11 | khasan
# Processing Record 34 of Set 11 | archidona
# Processing Record 35 of Set 11 | tazovskiy
# Processing Record 36 of Set 11 | baglung
# Processing Record 37 of Set 11 | srednekolymsk
# Processing Record 38 of Set 11 | ostersund
# Processing Record 39 of Set 11 | manavalakurichi
# Processing Record 40 of Set 11 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 41 of Set 11 | calama
# Processing Record 42 of Set 11 | jiazi
# Processing Record 43 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 11 | kushima
# Processing Record 45 of Set 11 | giyon
# Processing Record 46 of Set 11 | hvolsvollur
# Processing Record 47 of Set 11 | takoradi
# Processing Record 48 of Set 11 | padang
# Processing Record 49 of Set 11 | saint paul
# Processing Record 50 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 1 of Set 12 | iqaluit
# Processing Record 2 of Set 12 | mendi
# Processing Record 3 of Set 12 | finschhafen
# Processing Record 4 of Set 12 | richards bay
# Processing Record 5 of Set 12 | sonamukhi
# Processing Record 6 of Set 12 | baoma
# Processing Record 7 of Set 12 | porterville
# Processing Record 8 of Set 12 | strelka
# Processing Record 9 of Set 12 | montana
# Processing Record 10 of Set 12 | burns lake
# Processing Record 11 of Set 12 | kentau
# Processing Record 12 of Set 12 | matagami
# Processing Record 13 of Set 12 | poroshkovo
# Processing Record 14 of Set 12 | batagay-alyta
# Processing Record 15 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 16 of Set 12 | baculin
# Processing Record 17 of Set 12 | saquarema
# Processing Record 18 of Set 12 | la primavera
# Processing Record 19 of Set 12 | birjand
# Processing Record 20 of Set 12 | kidal
# Processing Record 21 of Set 12 | mutsu
# Processing Record 22 of Set 12 | buala
# Processing Record 23 of Set 12 | lakes entrance
# Processing Record 24 of Set 12 | mwinilunga
# Processing Record 25 of Set 12 | fort nelson
# Processing Record 26 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 27 of Set 12 | grindavik
# Processing Record 28 of Set 12 | rasipuram
# Processing Record 29 of Set 12 | pechora
# Processing Record 30 of Set 12 | prince rupert
# Processing Record 31 of Set 12 | kangaatsiaq
# Processing Record 32 of Set 12 | ambilobe
# Processing Record 33 of Set 12 | esil
# Processing Record 34 of Set 12 | bakel
# Processing Record 35 of Set 12 | lensk
# Processing Record 36 of Set 12 | nowy targ
# Processing Record 37 of Set 12 | thai nguyen
# Processing Record 38 of Set 12 | vallenar
# Processing Record 39 of Set 12 | chimbote
# Processing Record 40 of Set 12 | sawtell
# Processing Record 41 of Set 12 | walvis bay
# Processing Record 42 of Set 12 | shemysheyka
# Processing Record 43 of Set 12 | pula
# Processing Record 44 of Set 12 | gurupa
# Processing Record 45 of Set 12 | guajara
# Processing Record 46 of Set 12 | bourail
# Processing Record 47 of Set 12 | lipin bor
# Processing Record 48 of Set 12 | rantepao
# Processing Record 49 of Set 12 | manta
# Processing Record 50 of Set 12 | sao felix do xingu
# Processing Record 1 of Set 13 | blackwater
# Processing Record 2 of Set 13 | calamar
# Processing Record 3 of Set 13 | raudeberg
# Processing Record 4 of Set 13 | ust-omchug
# Processing Record 5 of Set 13 | nagato
# Processing Record 6 of Set 13 | podporozhye
# Processing Record 7 of Set 13 | vanderhoof
# Processing Record 8 of Set 13 | korgen
# Processing Record 9 of Set 13 | torquay
# Processing Record 10 of Set 13 | lumberton
# Processing Record 11 of Set 13 | naze
# Processing Record 12 of Set 13 | porosozero
# Processing Record 13 of Set 13 | sioux lookout
# Processing Record 14 of Set 13 | tiarei
# Processing Record 15 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 13 | sebeta
# Processing Record 17 of Set 13 | mishan
# Processing Record 18 of Set 13 | khuzdar
# Processing Record 19 of Set 13 | mponela
# Processing Record 20 of Set 13 | porto novo
# Processing Record 21 of Set 13 | monduli
# Processing Record 22 of Set 13 | sistranda
# Processing Record 23 of Set 13 | rocha
# Processing Record 24 of Set 13 | ruian
# City not found. Skipping...
# Processing Record 25 of Set 13 | klyuchi
# Processing Record 26 of Set 13 | araceli
# Processing Record 27 of Set 13 | tias
# Processing Record 28 of Set 13 | atherton
# Processing Record 29 of Set 13 | lososina
# Processing Record 30 of Set 13 | barcelos
# Processing Record 31 of Set 13 | isla aguada
# Processing Record 32 of Set 13 | zolotukhino
# Processing Record 33 of Set 13 | niquero
# Processing Record 34 of Set 13 | altus
# Processing Record 35 of Set 13 | dali
# Processing Record 36 of Set 13 | berdychiv
# Processing Record 37 of Set 13 | teguldet
# Processing Record 38 of Set 13 | ambovombe
# Processing Record 39 of Set 13 | skibbereen
# Processing Record 40 of Set 13 | shimoda
# Processing Record 41 of Set 13 | lexington
# Processing Record 42 of Set 13 | great falls
# Processing Record 43 of Set 13 | walla walla
# Processing Record 44 of Set 13 | khani
# Processing Record 45 of Set 13 | mugur-aksy
# Processing Record 46 of Set 13 | sahrak
# City not found. Skipping...
# Processing Record 47 of Set 13 | tanjong karang
# City not found. Skipping...
# Processing Record 48 of Set 13 | le port
# Processing Record 49 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 50 of Set 13 | high prairie
# Processing Record 1 of Set 14 | chulym
# Processing Record 2 of Set 14 | licata
# Processing Record 3 of Set 14 | telhara
# Processing Record 4 of Set 14 | kalnciems
# Processing Record 5 of Set 14 | iquitos
# Processing Record 6 of Set 14 | queanbeyan
# Processing Record 7 of Set 14 | pangai
# Processing Record 8 of Set 14 | saint-pierre
# Processing Record 9 of Set 14 | viedma
# Processing Record 10 of Set 14 | jining
# Processing Record 11 of Set 14 | stephenville
# Processing Record 12 of Set 14 | quelimane
# Processing Record 13 of Set 14 | bayeux
# Processing Record 14 of Set 14 | falmouth
# Processing Record 15 of Set 14 | saint-georges
# Processing Record 16 of Set 14 | churapcha
# Processing Record 17 of Set 14 | urubicha
# Processing Record 18 of Set 14 | san patricio
# Processing Record 19 of Set 14 | paamiut
# Processing Record 20 of Set 14 | pochutla
# Processing Record 21 of Set 14 | imbituba
# Processing Record 22 of Set 14 | nizwa
# Processing Record 23 of Set 14 | ust-ilimsk
# Processing Record 24 of Set 14 | caravelas
# Processing Record 25 of Set 14 | pavlodar
# Processing Record 26 of Set 14 | manokwari
# Processing Record 27 of Set 14 | brae
# Processing Record 28 of Set 14 | san policarpo
# Processing Record 29 of Set 14 | coahuayana
# Processing Record 30 of Set 14 | pauini
# Processing Record 31 of Set 14 | roald
# Processing Record 32 of Set 14 | prieta
# Processing Record 33 of Set 14 | kandalaksha
# Processing Record 34 of Set 14 | balaipungut
# Processing Record 35 of Set 14 | jacareacanga
# Processing Record 36 of Set 14 | evensk
# Processing Record 37 of Set 14 | shimanovsk
# Processing Record 38 of Set 14 | aykhal
# Processing Record 39 of Set 14 | la ligua
# Processing Record 40 of Set 14 | le havre
# Processing Record 41 of Set 14 | colquechaca
# Processing Record 42 of Set 14 | ukiah
# Processing Record 43 of Set 14 | silvan
# Processing Record 44 of Set 14 | oyem
# Processing Record 45 of Set 14 | opatija
# Processing Record 46 of Set 14 | si sa ket
# Processing Record 47 of Set 14 | puerto escondido
# Processing Record 48 of Set 14 | pokhara
# Processing Record 49 of Set 14 | pali
# Processing Record 50 of Set 14 | longkou
# Processing Record 1 of Set 15 | seymchan
# Processing Record 2 of Set 15 | yagodnoye
# Processing Record 3 of Set 15 | molepolole
# Processing Record 4 of Set 15 | saint-joseph
# Processing Record 5 of Set 15 | tura
# Processing Record 6 of Set 15 | twante
# Processing Record 7 of Set 15 | mananara
# Processing Record 8 of Set 15 | sydney
# Processing Record 9 of Set 15 | roma
# Processing Record 10 of Set 15 | pacific grove
# Processing Record 11 of Set 15 | takaka
# Processing Record 12 of Set 15 | dabakala
# Processing Record 13 of Set 15 | pasni
# Processing Record 14 of Set 15 | scottsbluff
# Processing Record 15 of Set 15 | constitucion
# Processing Record 16 of Set 15 | aleksandrovsk-sakhalinskiy
# Processing Record 17 of Set 15 | tongren
# Processing Record 18 of Set 15 | sirsi
# Processing Record 19 of Set 15 | tambopata
# Processing Record 20 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 15 | half moon bay
# Processing Record 22 of Set 15 | shieli
# Processing Record 23 of Set 15 | la palma
# Processing Record 24 of Set 15 | odlabari
# Processing Record 25 of Set 15 | igarka
# Processing Record 26 of Set 15 | comodoro rivadavia
# Processing Record 27 of Set 15 | palanga
# Processing Record 28 of Set 15 | terrace bay
# Processing Record 29 of Set 15 | burica
# City not found. Skipping...
# Processing Record 30 of Set 15 | earlston
# Processing Record 31 of Set 15 | dubbo
# Processing Record 32 of Set 15 | palmer
# Processing Record 33 of Set 15 | peace river
# Processing Record 34 of Set 15 | pimentel
# Processing Record 35 of Set 15 | vilhena
# Processing Record 36 of Set 15 | letka
# Processing Record 37 of Set 15 | tutoia
# Processing Record 38 of Set 15 | esso
# Processing Record 39 of Set 15 | sechura
# Processing Record 40 of Set 15 | luderitz
# Processing Record 41 of Set 15 | la rioja
# Processing Record 42 of Set 15 | escuinapa
# Processing Record 43 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 15 | geilo
# Processing Record 45 of Set 15 | nalgonda
# Processing Record 46 of Set 15 | iquique
# Processing Record 47 of Set 15 | buraydah
# Processing Record 48 of Set 15 | hilton head island
# Processing Record 49 of Set 15 | vao
# Processing Record 50 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 16 | vanersborg
# Processing Record 2 of Set 16 | mandalgovi
# Processing Record 3 of Set 16 | orlik
# Processing Record 4 of Set 16 | bafq
# Processing Record 5 of Set 16 | krupanj
# Processing Record 6 of Set 16 | ko samui
# Processing Record 7 of Set 16 | hammerfest
# Processing Record 8 of Set 16 | okhotsk
# Processing Record 9 of Set 16 | nerchinskiy zavod
# Processing Record 10 of Set 16 | xiuyan
# Processing Record 11 of Set 16 | baijiantan
# Processing Record 12 of Set 16 | watertown
# Processing Record 13 of Set 16 | touros
# Processing Record 14 of Set 16 | monchegorsk
# Processing Record 15 of Set 16 | wewak
# Processing Record 16 of Set 16 | venafro
# Processing Record 17 of Set 16 | farah
# Processing Record 18 of Set 16 | sakakah
# Processing Record 19 of Set 16 | kanniyakumari
# Processing Record 20 of Set 16 | fukue
# Processing Record 21 of Set 16 | ust-tsilma
# Processing Record 22 of Set 16 | ixtapa
# Processing Record 23 of Set 16 | shingu

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0     Sinnamary      GF   5.38  -52.95     81.07        77          16
# 1  Kruisfontein      ZA -34.00   24.73     57.60        46          69
# 2      Thompson      CA  55.74  -97.86     39.20        80          75
# 3        Avarua      CK -21.21 -159.78     73.40        83          90
# 4    Morant Bay      JM  17.88  -76.41     81.00        94          75
# 5      Progreso      MX  21.28  -89.67     91.40        63          75
# 6     Taoudenni      ML  22.68   -3.98     90.75        15          29
# 7       Ushuaia      AR -54.80  -68.30     44.60        75          75
# 8       Xai-Xai      MZ -25.05   33.64     61.38        88           6
# 9    Cheboksary      RU  56.13   47.25     53.60        75          40
#
#    Wind Speed          Current Description
# 0       11.61                   few clouds
# 1        7.11                broken clouds
# 2       13.87  light intensity shower rain
# 3        3.36                   light rain
# 4       11.41                  shower rain
# 5       11.92                broken clouds
# 6        7.23             scattered clouds
# 7        5.82                broken clouds
# 8        3.94                    clear sky
# 9        8.95             scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
